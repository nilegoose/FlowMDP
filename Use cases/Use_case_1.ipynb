# %% [markdown]
# The paper [The Visual Language of Multidimensional Data Projection: A Visualization Taxonomy and Informed Insights](https://) discusses the need for alternative ways to think about visualizing Multi-Dimensional Projection(MDP). This project shows the alternative ways for MDPs using three different use cases. There exist complex relationships between data instances, therefore there is need to explore different visualization techniques (encoding and interaction) to make clear these complexities. The goal of the project is not to propose new visualization rather to explore the design space of alternatives visualization techniques.
#
# </br>
#
# ## Use case 1:  Class Separation
# #### Class separation through visualization
# In this notebook, we start exploring class separation using visualization techniques, a crucial step in understanding how different categories or classes within a dataset relate to one another. Class separation is essential for assessing the effectiveness of classification models, as it provides insights into the distinguishability of classes based on their features.
#
# ##### Dataset Description
#
# 1. Title: Wisconsin Breast Cancer Database (January 8, 1991)
#
# 2. Sources:
#    -- Dr. WIlliam H. Wolberg (physician)
#       University of Wisconsin Hospitals
#       Madison, Wisconsin
#       USA
#    -- Donor: Olvi Mangasarian (mangasarian@cs.wisc.edu)
#       Received by David W. Aha (aha@cs.jhu.edu)
#    -- Date: 15 July 1992

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <h3 data-toggle="list"  role="tab" aria-controls="home"><p style="font-size : 30px"><font color="darkgrey">Content<font/></p></h3>
#
# 1. [<font color="darkgrey"> Dataset<font/>](#1)
#     - 1.1 [<font color="darkgrey"> Overview<font/>](#1.1)
#     - 1.2 [<font color="darkgrey"> Preprocessing<font/>](#1.2)
#     - 1.3 [<font color="darkgrey"> Dimensionality Reduction<font/>](#1.3)
#
# 2. [<font color="darkgrey">Visual Perspectives<font/>](#2)
#     - 2.1. [<font color="darkgrey"> One Dimension (1D)<font/>](#2.1)
#         - 2.1.1 [<font color="darkgrey"> 1D Strip plot <font/>](#2.1.1)
#         - 2.1.2 [<font color="darkgrey"> Box Plot <font/>](#2.1.2)
#         - 2.1.3 [<font color="darkgrey"> Histogram <font/>](#2.1.3)
#         - 2.1.4 [<font color="darkgrey"> Violin Plot <font/>](#2.1.4)
#     - 2.2. [<font color="darkgrey"> Two Dimensions (2D)<font/>](#2.2)
#         - 2.2.1 [<font color="darkgrey">Scatterplot<font/>](#2.2.1)
#         - 2.2.2 [<font color="darkgrey"> Contour<font/>](#2.2.2)
#         - 2.2.3 [<font color="darkgrey"> Heatmap<font/>](#2.2.3)
#         - 2.2.4 [<font color="darkgrey"> Dendrogram <font/>](#2.2.4)
#         - 2.2.5 [<font color="darkgrey"> Parallel Coordinate Plot <font/>](#2.2.5)

# %% [markdown]
# <font size="+3" color="grey"><b>1. Dataset </b></font><br><a id="1"></a>
# <a href="#top" class="btn-xs btn-danger" role="button" aria-pressed="true" style="color:white" data-toggle="popover">Go back to the TOP</a>

# %%
# Import packages data overview
import pandas as pd

# set package env
import sys, os
# Move one step up from the current working directory
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# Create a directory
output_dir = "images"
os.makedirs(output_dir, exist_ok=True)

# Replace with the path to your .data file
data_file_path = '../Data/Dataset_2/Breast_Cancer_Wisconsin_Original/breast-cancer-wisconsin.data'

# Define custom column headers (Replace these with your actual headers)
column_headers = [
    "Sample code number", "Clump Thickness", "Uniformity of Cell Size", 
    "Uniformity of Cell Shape", "Marginal Adhesion", "Bare Nuclei", 
    "Bland Chromatin", "Single Epithelial Cell Size", "Normal Nucleoli", 
    "Mitoses", "Class"
]

# Read the .data file and set the headers
df = pd.read_csv(data_file_path,  delimiter=',', header=None, names=column_headers)

# %% [markdown]
# <font size="+2" color="grey"><b>1.1. Overview </b></font><br>

# %%
df
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1000025                5                        1
# 1               1002945                5                        4
# 2               1015425                3                        1
# 3               1016277                6                        8
# 4               1017023                4                        1
# ..                  ...              ...                      ...
# 694              776715                3                        1
# 695              841769                2                        1
# 696              888820                5                       10
# 697              897471                4                        8
# 698              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Bare Nuclei Bland Chromatin  \
# 0                           1                  1            2               1
# 1                           4                  5            7              10
# 2                           1                  1            2               2
# 3                           8                  1            3               4
# 4                           1                  3            2               1
# ..                        ...                ...          ...             ...
# 694                         1                  1            3               2
# 695                         1                  1            2               1
# 696                        10                  3            7               3
# 697                         6                  4            3               4
# 698                         8                  5            4               5
#
#      Single Epithelial Cell Size  Normal Nucleoli  Mitoses  Class
# 0                              3                1        1      2
# 1                              3                2        1      2
# 2                              3                1        1      2
# 3                              3                7        1      2
# 4                              3                1        1      2
# ..                           ...              ...      ...    ...
# 694                            1                1        1      2
# 695                            1                1        1      2
# 696                            8               10        2      4
# 697                           10                6        1      4
# 698                           10                4        1      4
#
# [699 rows x 11 columns]

# %% [markdown]
# <font size="+2" color="grey"><b>1.2. Preprocessing </b></font><br>

# %%
from Implementations.imputation import Preprocessor
# Initialize the Preprocessor class with the dataset
preprocessor = Preprocessor(df)
# We have decided to excempt the target variable from being preprocessed
exempt_columns = ['Class']
processed_data = preprocessor.preprocess(
    strategy='mean', 
    remove_missing=False, 
    exempt_columns=exempt_columns
)

# %% [markdown]
# <font size="+2" color="grey"><b>1.3. Dimensionality Reduction </b></font><br>

# %% [markdown]
# <font size="+1" color="grey"><b> Dimensionality Reduction Techniques </b></font><br>
#
# Dimensionality reduction simplifies complex data by reducing the number of features, making it easier to visualize and understand.
#
# **PCA (Principal Component Analysis)**
# - **Purpose**: Transforms data into a new space, capturing the most important patterns.
# - **Method**: Projects high-dimensional data onto a lower-dimensional space while retaining essential information.
#
# **t-SNE (t-Distributed Stochastic Neighbor Embedding)**
# - **Purpose**: Visualizes high-dimensional data in a lower dimension.
# - **Method**: Keeps similar points close together to help identify clusters and patterns.
#
# **UMAP (Uniform Manifold Approximation and Projection)**
# - **Purpose**: Reduces dimensions while preserving both global and local structures in data.
# - **Method**: Effective for larger datasets, showing both major patterns and finer details.
#
# After applying these techniques, visualizations in 2D plots make it easier to see and interpret complex data patterns.

# %%
from Implementations.dimensionality_reduction import DimensionalityReduction
import pandas as pd
# Initialize DimensionalityReduction class
dr = DimensionalityReduction(data=df, target_column='Class')
# Apply different dimensionality reduction techniques
pca_df = dr.apply_pca()
tsne_df = dr.apply_tsne()
umap_df = dr.apply_umap()
complete_dataset = pd.concat([pca_df, tsne_df, umap_df], axis=1)

# combine reduced dimension into one
merged_datasets = complete_dataset[[
    # "PCA_Component_1", "PCA_Component_2", 
    "t-SNE_Component_1", "t-SNE_Component_2", 
    # "UMAP_Component_1", "UMAP_Component_2", 
    "Class"
]]
merged_datasets = merged_datasets.groupby(merged_datasets.columns, axis=1).first()
merged_datasets['Class2'] = merged_datasets['Class'].replace({2.0: 'benign', 4.0: 'malignant'})
# Out:
# /Users/AwotoroE-Dev/Desktop/FlowMDP/.env/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# /var/folders/95/gt0pqtjx3r76yhhy2b1fc02c0000gp/T/ipykernel_97937/1249470791.py:18: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.

# %% [markdown]
# <font size="+9" color="grey"><b> 2.1 1D</b></font><font size="+1" color="grey"><b> ( Class Separation) </b></font><br>
#
#
# <h2 style="font-size: 1.2em;">1D Types</h2>
# <ul>
#     <li>Strip Plot</li>
#     <li>Histogram</li>
#     <li>Box Plot</li>
#     <li>Violin Plot</li>
# </ul>

# %%
from Implementations.visualization import create_combined_chart
scatter_plot_single, gaussian_jitter, box_with_jitter, histogram_shade, combined_chart = create_combined_chart(
    merged_datasets, "t-SNE_Component_1", "t-SNE_Component_2",
    main_attr_color_range=["#1f78b4", "#b2df8a"],
    main_color_range=["#66c2a5", "#fc8d62"],
    attr_color_range=["#66c2a5", "#fc8d62", "#66c2a5", "#fc8d62"],
    attribute_nomeclature=["t-SNE 1", "t-SNE 2"],
    attr_color_domain=[
        "benign t-SNE 1",
        "malignant t-SNE 1",
        "benign t-SNE 2",
        "malignant t-SNE 2",
    ],
    width_single=800,
    height_single=400, 
    jitter_size=50
)
# combined_chart
combined_chart.configure_title(
    fontSize=18  # Title font size
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18,
    orient="bottom", title=None, padding=5, labelLimit=200, 
    # columns=3
)
# .save('../../images/case1_combined.png', format='png', scale_factor=2)

# %%
combined_chart.configure_title(
    fontSize=18
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18,
    orient="bottom", title=None, padding=5, labelLimit=200, 
    # columns=3
)
# Out:
# alt.HConcatChart(...)

# %%
scatter_plot_single.configure_title(
    fontSize=18
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18,
    orient="bottom", title=None, padding=5, labelLimit=200, 
    # columns=3
)
# .save('../../images/case1_scatter_plot.png', format='png', scale_factor=2)

# %% [markdown]
# <font size="+1" color="grey"><b> 2.1.1 Strip Plot </b></font>

# %%
gaussian_jitter.configure_title(
    fontSize=18
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18,
    orient="bottom", title=None, padding=5, labelLimit=200, 
    # columns=3
)
# .save('../../images/case1_strip_plot.png', format='png', scale_factor=2)

# %% [markdown]
# <font size="+1" color="grey"><b> 2.1.2 Box Plot </b></font>

# %%
box_with_jitter.configure_title(
    fontSize=18
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18,
    orient="bottom", title=None, padding=5, labelLimit=200, 
    # columns=3
)
# .save('../../images/case1_box_plot_with_strip_plot.png', format='png', scale_factor=2)

# %% [markdown]
# <font size="+1" color="grey"><b> 2.1.3 Histogram Plot</b></font>

# %%
histogram_shade.configure_title(
    fontSize=18
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18,
    orient="bottom", title=None, padding=5, labelLimit=200, 
    # columns=3
)
# .save('../../images/case1_histogram_plot.png', format='png', scale_factor=2)

# %% [markdown]
# <font size="+1" color="grey"><b> 2.1.4 Violin Plot</b></font><br/>
# ***Violin Plot (1D): This is here because we could not do this in Altair***

# %%
from Implementations.visualization import create_plotly_violin_plots
violin_plot = create_plotly_violin_plots(merged_datasets, x="t-SNE_Component_1", y="t-SNE_Component_2")
violin_plot.update_layout(
    font=dict(size=18),
    title_font=dict(size=24),
    xaxis=dict(title_font=dict(size=20), tickfont=dict(size=16)),
    yaxis=dict(title_font=dict(size=20), tickfont=dict(size=16))

)
# .write_image("../../images/case1_violin_plot.png", width=800, height=400, scale=2)
display(violin_plot)

# %% [markdown]
# <font size="+9" color="grey"><b>2.2. 2D</b></font><font size="+1" color="grey"><b> ( Class Separation) </b></font><br>
#
# <h2 style="font-size: 1.2em;">2D Types or More</h2>
# <ul>
#     <li>Scattered Plot</li>
#     <li>Density Contour Plot</li>
#     <li>Heatmap Plot</li>
#     <li>Parallel Co-ordinate Plot</li>
#     <li>Dendrogram Plot</li>
# </ul>

# %%
from Implementations.visualization import create_2Dinteractive_plots
scatter_widget, contour_widget, density_widget, parallel_widget, dendro_widget, grid_layout = create_2Dinteractive_plots(merged_datasets, 't-SNE_Component_1', 't-SNE_Component_2', target_numeric="Class", target="Class2")

# %% [markdown]
# <font size="+1" color="grey"><b> 2.2.1 Scatter Plot</b></font><br/>

# %%
scatter_plot_2d = scatter_widget.update_layout(
    # width=800,
    # height=400,
    xaxis=dict(
        range=[-24, 34],
        gridcolor='LightGray',
        showgrid=True,
        zeroline=True,         # Show 0 line
        zerolinecolor="gray",  # Set color for 0 line
        zerolinewidth=1,
        title_font=dict(size=20), 
        tickfont=dict(size=16)
    ),
    yaxis=dict(
        range=[-15, 15],
        gridcolor='LightGray',
        showgrid=True,
        zeroline=True,         # Show 0 line
        zerolinecolor="gray",  # Set color for 0 line
        zerolinewidth=1,
        title_font=dict(size=20), 
        tickfont=dict(size=16)  
    ),
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    font=dict(size=18),
    title_font=dict(size=24),
)

# scatter_plot_2d.write_image("../../images/case1_2d_scatter_plot.png", width=800, height=400, scale=2)
display(scatter_plot_2d)
# Out:
# FigureWidget({
#     'data': [{'hovertemplate': 'Class2=benign<br>t-SNE_Component_1=%{x}<br>t-SNE_Component_2=%{y}<extra></extra>',
#               'legendgroup': 'benign',
#               'marker': {'color': '#66c2a5', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'benign',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '22b16c90-aae2-4c8c-a46e-53227d4e5ad9',
#               'x': array([ -1.35362554,  12.17535686,   3.40371871, ...,  -9.22936821,
#                            -9.61014843, -17.46323204]),
#               'xaxis': 'x',
#               'y': array([-1.69337952, -4.56390476,  4.65125751, ...,  6.85571718, 12.35418034,
#                           10.53393364]),
#               'yaxis': 'y'},
#              {'hovertemplate': ('Class2=malignant<br>t-SNE_Comp' ... 'omponent_2=%{y}<extra></extra>'),
#               'legendgroup': 'malignant',
#               'marker': {'color': '#fc8d62', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'malignant',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '37ffaf8c-a966-46f3-a34b-76076be680d4',
#               'x': array([24.80899811,  8.85287666, 21.33534241, ..., 23.55991936, 19.96989059,
#                           19.96037483]),
#               'xaxis': 'x',
#               'y': array([1.03889656, 3.65413165, 7.64416409, ..., 2.67678857, 3.93712044,
#                           4.05621529]),
#               'yaxis': 'y'}],
#     'layout': {'font': {'size': 18},
#                'legend': {'orientation': 'h',
#                           'title': {'text': 'Class2'},
#                           'tracegroupgap': 0,
#                           'x': 0.5,
#                           'xanchor': 'center',
#                           'y': 1.1,
#                           'yanchor': 'top'},
#                'margin': {'t': 60},
#                'paper_bgcolor': 'rgba(0,0,0,0)',
#                'plot_bgcolor': 'rgba(0,0,0,0)',
#                'showlegend': True,
#                'template': '...',
#                'title': {'font': {'size': 24}},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'gridcolor': 'LightGray',
#                          'range': [-24, 34],
#                          'showgrid': True,
#                          'tickfont': {'size': 16},
#                          'title': {'font': {'size': 20}, 'text': 't-SNE_Component_1'},
#                          'zeroline': True,
#                          'zerolinecolor': 'gray',
#                          'zerolinewidth': 1},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.0, 1.0],
#                          'gridcolor': 'LightGray',
#                          'range': [-15, 15],
#                          'showgrid': True,
#                          'tickfont': {'size': 16},
#                          'title': {'font': {'size': 20}, 'text': 't-SNE_Component_2'},
#                          'zeroline': True,
#                          'zerolinecolor': 'gray',
#                          'zerolinewidth': 1}}
# })

# %% [markdown]
# <font size="+1" color="grey"><b> 2.2.2 Contour Plot</b></font><br/>

# %%
contour_plot_2d = contour_widget.update_traces(line=dict(width=2)).update_layout(
    # width=800,
    # height=600,
    xaxis=dict(
        range=[-35, 40],
        gridcolor='grey',
        showgrid=True,
        zeroline=True,         # Show 0 line
        zerolinecolor="gray",  # Set color for 0 line
        zerolinewidth=1,        # Set width for 0 line
        title_font=dict(size=20), 
        tickfont=dict(size=16)
    ),
    yaxis=dict(
        range=[-20, 20],
        gridcolor='grey',
        showgrid=True,
        zeroline=True,         # Show 0 line
        zerolinecolor="gray",  # Set color for 0 line
        zerolinewidth=1,        # Set width for 0 line
        title_font=dict(size=20), 
        tickfont=dict(size=16)
    ),
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    font=dict(size=18),
    title_font=dict(size=24)

)

# contour_plot_2d.write_image("../../images/case1_2d_contour_plot.png", width=800, height=400, scale=2)
display(contour_plot_2d)
# Out:
# FigureWidget({
#     'data': [{'contours': {'coloring': 'none'},
#               'hovertemplate': ('Class2=benign<br>t-SNE_Compone' ... '}<br>count=%{z}<extra></extra>'),
#               'legendgroup': 'benign',
#               'line': {'color': '#66c2a5', 'width': 2},
#               'name': 'benign',
#               'showlegend': True,
#               'type': 'histogram2dcontour',
#               'uid': 'aa81338b-2ae8-4b84-923a-a5a5cb9683af',
#               'x': array([ -1.35362554,  12.17535686,   3.40371871, ...,  -9.22936821,
#                            -9.61014843, -17.46323204]),
#               'xaxis': 'x',
#               'xbingroup': 'x',
#               'y': array([-1.69337952, -4.56390476,  4.65125751, ...,  6.85571718, 12.35418034,
#                           10.53393364]),
#               'yaxis': 'y',
#               'ybingroup': 'y'},
#              {'contours': {'coloring': 'none'},
#               'hovertemplate': ('Class2=malignant<br>t-SNE_Comp' ... '}<br>count=%{z}<extra></extra>'),
#               'legendgroup': 'malignant',
#               'line': {'color': '#fc8d62', 'width': 2},
#               'name': 'malignant',
#               'showlegend': True,
#               'type': 'histogram2dcontour',
#               'uid': '58781edb-34e9-4863-a776-e90702f48e9a',
#               'x': array([24.80899811,  8.85287666, 21.33534241, ..., 23.55991936, 19.96989059,
#                           19.96037483]),
#               'xaxis': 'x',
#               'xbingroup': 'x',
#               'y': array([1.03889656, 3.65413165, 7.64416409, ..., 2.67678857, 3.93712044,
#                           4.05621529]),
#               'yaxis': 'y',
#               'ybingroup': 'y'}],
#     'layout': {'font': {'size': 18},
#                'legend': {'title': {'text': 'Class2'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'paper_bgcolor': 'rgba(0,0,0,0)',
#                'plot_bgcolor': 'rgba(0,0,0,0)',
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 24}},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'gridcolor': 'grey',
#                          'range': [-35, 40],
#                          'showgrid': True,
#                          'tickfont': {'size': 16},
#                          'title': {'font': {'size': 20}, 'text': 't-SNE_Component_1'},
#                          'zeroline': True,
#                          'zerolinecolor': 'gray',
#                          'zerolinewidth': 1},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.0, 1.0],
#                          'gridcolor': 'grey',
#                          'range': [-20, 20],
#                          'showgrid': True,
#                          'tickfont': {'size': 16},
#                          'title': {'font': {'size': 20}, 'text': 't-SNE_Component_2'},
#                          'zeroline': True,
#                          'zerolinecolor': 'gray',
#                          'zerolinewidth': 1}}
# })

# %% [markdown]
# <font size="+1" color="grey"><b> 2.2.3 Heatmap Plot</b></font><br/>

# %%
heatmap_plot_2d = density_widget.update_layout(
    # width=800,
    # height=600,
    font=dict(size=18),
    title_font=dict(size=24),
    xaxis=dict(title_font=dict(size=20), tickfont=dict(size=16)),
    yaxis=dict(title_font=dict(size=20), tickfont=dict(size=16))
)

# heatmap_plot_2d.write_image("../../images/case1_2d_heatmap_plot.png", width=800, height=400, scale=2)
display(heatmap_plot_2d)
# Out:
# FigureWidget({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 't-SNE_Component_1=%{x}<br>t-SNE_Component_2=%{y}<br>count=%{z}<extra></extra>',
#               'name': '',
#               'type': 'histogram2d',
#               'uid': '21669155-efef-4409-a16c-cefb596bf5c8',
#               'x': array([-1.35362554, 12.17535686,  3.40371871, ..., 23.55991936, 19.96989059,
#                           19.96037483]),
#               'xaxis': 'x',
#               'xbingroup': 'x',
#               'y': array([-1.69337952, -4.56390476,  4.65125751, ...,  2.67678857,  3.93712044,
#                            4.05621529]),
#               'yaxis': 'y',
#               'ybingroup': 'y'}],
#     'layout': {'coloraxis': {'colorbar': {'title': {'text': 'count'}}, 'colorscale': [[0, 'white'], [1, 'black']]},
#                'font': {'size': 18},
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 24}},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'tickfont': {'size': 16},
#                          'title': {'font': {'size': 20}, 'text': 't-SNE_Component_1'}},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.0, 1.0],
#                          'tickfont': {'size': 16},
#                          'title': {'font': {'size': 20}, 'text': 't-SNE_Component_2'}}}
# })

# %% [markdown]
# <font size="+1" color="grey"><b> 2.2.4 Dendrogram Plot</b></font><br/>

# %%
treemap_plot_2d = (dendro_widget.update_layout(
    # width=800,
    # height=600,
    font=dict(size=18),
    title_font=dict(size=24),
    xaxis=dict(title_font=dict(size=20), tickfont=dict(size=16)),
    yaxis=dict(title_font=dict(size=20), tickfont=dict(size=16))
))

# treemap_plot_2d.write_image("../../images/case1_2d_treemap_plot.png", width=800, height=400, scale=2)
display(treemap_plot_2d)
# Out:
# FigureWidget({
#     'data': [{'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '93dcbf5b-8144-4633-98b5-291686301cd1',
#               'x': [5.0, 5.0, 15.0, 15.0],
#               'y': [0.0, 1.1752095444771093, 1.1752095444771093, 0.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '644c2963-5a0f-4d12-a081-56b456534a67',
#               'x': [35.0, 35.0, 45.0, 45.0],
#               'y': [0.0, 0.10109423932970227, 0.10109423932970227, 0.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '0b667c51-09d1-4f55-a64b-11c4d7d53513',
#               'x': [25.0, 25.0, 40.0, 40.0],
#               'y': [0.0, 0.18228344254082002, 0.18228344254082002,
#                     0.10109423932970227]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '846eff71-eb5a-4ef2-9dfb-bd8d7ea4d3ac',
#               'x': [55.0, 55.0, 65.0, 65.0],
#               'y': [0.0, 0.2556145341657901, 0.2556145341657901, 0.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'd7fc42cc-1ea6-4719-b66b-bfe24826084c',
#               'x': [32.5, 32.5, 60.0, 60.0],
#               'y': [0.18228344254082002, 0.739254940681428, 0.739254940681428,
#                     0.2556145341657901]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '4637eedc-ae7a-4a07-a0d7-b2a45ac48129',
#               'x': [75.0, 75.0, 85.0, 85.0],
#               'y': [0.0, 0.31049981001983923, 0.31049981001983923, 0.0]},
#              {'line': {'color': 'black', 'width': 1},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid':

#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '342eab61-e269-4e7e-8a66-c04f1eefb84b',
#               'x': [6445.0],
#               'y': [1.1275871105627828]},
#              {'mode': 'text',
#               'text': '342',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '212c0ab7-f829-4ec7-a6df-b4b17df21256',
#               'x': [6505.0],
#               'y': [0.0]},
#              {'mode': 'text',
#               'text': '445',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'aed90ff8-af40-450f-85d0-72c007fa5772',
#               'x': [6495.0],
#               'y': [0.13296128376389912]},
#              {'mode': 'text',
#               'text': '354',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '08c65ee4-5c0b-4205-b770-2907f256694e',
#               'x': [6525.0],
#               'y': [0.4812080394402404]},
#              {'mode': 'text',
#               'text': '376',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '49297325-b88b-4306-9bfd-f4d3da16c57e',
#               'x': [6502.5],
#               'y': [1.916525847904951]},
#              {'mode': 'text',
#               'text': '327',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '31855ce7-f101-459d-bd81-7f65fa5eac99',
#               'x': [6454.375],
#               'y': [3.52113190577764]},
#              {'mode': 'text',
#               'text': '577',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '4c697831-00e3-4fb3-8d57-81d2d849965c',
#               'x': [6379.6875],
#               'y': [7.694994737532147]},
#              {'mode': 'text',
#               'text': '578',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'e7bf9950-df28-4aec-8ae9-095591b64ff6',
#               'x': [6247.5],
#               'y': [8.781324728178511]},
#              {'mode': 'text',
#               'text': '377',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'b8d471e9-866a-41a6-9d44-4d50d5cd4513',
#               'x': [6113.28125],
#               'y': [17.674500683468825]},
#              {'mode': 'text',
#               'text': '314',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '8c3cfeb6-d4b5-4459-b65f-095e7dbbbbd9',
#               'x': [6555.0],
#               'y': [0.7789380537546666]},
#              {'mode': 'text',
#               'text': '338',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'e1769d69-c766-4f39-9c74-ec860ef0529d',
#               'x': [6545.0],
#               'y': [1.4185117764046067]},
#              {'mode': 'text',
#               'text': '277',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '8f0e4048-ac16-4133-8c0a-8af21368c198',
#               'x': [6585.0],
#               'y': [0.5622085491239863]},
#              {'mode': 'text',
#               'text': '573',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'b492461b-4720-4677-91e7-439f11ccd2fb',
#               'x': [6575.0],
#               'y': [1.4278395688449244]},
#              {'mode': 'text',
#               'text': '438',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '788b40ce-7da5-4ce0-af5b-1f3a5e313fa7',
#               'x': [6552.5],
#               'y': [2.852516578209143]},
#              {'mode': 'text',
#               'text': '350',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'ccc70c36-df70-47a2-b94d-32013685b612',
#               'x': [6615.0],
#               'y': [0.6780255424772998]},
#              {'mode': 'text',
#               'text': '528',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'f952194c-25fa-4bdd-a4e9-07ba22e7820b',
#               'x': [6605.0],
#               'y': [1.8416210113802751]},
#              {'mode': 'text',
#               'text': '298',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'b29fcff9-2544-4123-86f4-06b3af725aa9',
#               'x': [6645.0],
#               'y': [1.2047090158596]},
#              {'mode': 'text',
#               'text': '332',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '0983df62-8dea-4bb7-96a2-1092f2e97d03',
#               'x': [6635.0],
#               'y': [2.4391504115336406]},
#              {'mode': 'text',
#               'text': '346',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '5c72f371-5323-4641-a333-715a10326e8a',
#               'x': [6612.5],
#               'y': [4.160179027818304]},
#              {'mode': 'text',
#               'text': '355',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '96287412-2e55-4a5b-a98c-cb42a11269b9',
#               'x': [6567.5],
#               'y': [7.203483230045472]},
#              {'mode': 'text',
#               'text': '531',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'fb6150c6-219d-464d-a11b-d70b87d945f4',
#               'x': [6665.0],
#               'y': [0.13399947253158476]},
#              {'mode': 'text',
#               'text': '580',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'b93933c1-d371-49d5-8706-e0e8594ca4d5',
#               'x': [6685.0],
#               'y': [1.3270376580968501]},
#              {'mode': 'text',
#               'text': '241',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '328aa929-0262-44b4-9d82-dbbe42a96a48',
#               'x': [6670.0],
#               'y': [2.0387046761444423]},
#              {'mode': 'text',
#               'text': '331',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'd12290dd-012b-4a1d-befd-3e532bf905e8',
#               'x': [6705.0],
#               'y': [0.11770927614543651]},
#              {'mode': 'text',
#               'text': '527',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '668b6829-d3d7-476e-ac4d-3d298a3ded52',
#               'x': [6745.0],
#               'y': [0.49660011702213047]},
#              {'mode': 'text',
#               'text': '442',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '5a12b55e-3c32-44dd-9c8e-f36b95b93c72',
#               'x': [6735.0],
#               'y': [0.8069470356869891]},
#              {'mode': 'text',
#               'text': '485',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '5ae011e2-8e6b-46cc-b4ed-2567ecba99ee',
#               'x': [6725.0],
#               'y': [1.283214489556918]},
#              {'mode': 'text',
#               'text': '443',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '25c66299-5989-4db1-b749-eae9010d53e6',
#               'x': [6710.0],
#               'y': [2.1485250099978606]},
#              {'mode': 'text',
#               'text': '694',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'b4ae1766-62c2-4647-ba9d-2a95d146688c',
#               'x': [6775.0],
#               'y': [0.26517125478920067]},
#              {'mode': 'text',
#               'text': '271',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '411c4076-24d8-4ff9-a3f4-63cbc6172447',
#               'x': [6765.0],
#               'y': [0.7567031363479567]},
#              {'mode': 'text',
#               'text': '575',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '2afca6b1-a436-43f7-8ce2-23c7f2fb05e4',
#               'x': [6795.0],
#               'y': [0.597354699147971]},
#              {'mode': 'text',
#               'text': '370',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '736fd25a-d571-4621-9de2-a6f4d217421b',
#               'x': [6825.0],
#               'y': [0.22083060205367466]},
#              {'mode': 'text',
#               'text': '606',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'e8c5084e-4d43-4984-871c-7769ebb910c0',
#               'x': [6815.0],
#               'y': [0.9463787176148907]},
#              {'mode': 'text',
#               'text': '372',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '23524d7c-13b4-4e3a-b1a3-c962e0b85212',
#               'x': [6800.0],
#               'y': [1.5461441598996528]},
#              {'mode': 'text',
#               'text': '521',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '5c17fc3e-37dc-48fe-b59d-78449524c913',
#               'x': [6772.5],
#               'y': [2.4102310304178913]},
#              {'mode': 'text',
#               'text': '526',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '5d237627-31d5-43aa-a4a9-02ca5cb4136f',
#               'x': [6721.875],
#               'y': [4.492772358250611]},
#              {'mode': 'text',
#               'text': '437',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '27f64b05-fca0-41e6-8483-4f11d16d62e2',
#               'x': [6855.0],
#               'y': [0.7848584924751564]},
#              {'mode': 'text',
#               'text': '688',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'c263fdf0-a535-4014-b7b7-8260a7bdb937',
#               'x': [6845.0],
#               'y': [1.289000808725984]},
#              {'mode': 'text',
#               'text': '484',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '6465fad3-016a-47c5-95c8-3dd1e5738147',
#               'x': [6885.0],
#               'y': [0.5054004459868735]},
#              {'mode': 'text',
#               'text': '576',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'd65f6c08-f6df-42d0-afce-442979de84c2',
#               'x': [6875.0],
#               'y': [1.9100423706672378]},
#              {'mode': 'text',
#               'text': '373',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'c1b1dd56-bf34-48a1-bd7b-b451fcad7d86',
#               'x': [6852.5],
#               'y': [3.1747494072991014]},
#              {'mode': 'text',
#               'text': '439',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'e704162a-0813-4a2f-be63-33915afca221',
#               'x': [6915.0],
#               'y': [0.34140850262117384]},
#              {'mode': 'text',
#               'text': '609',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '18ff553b-612a-4d6b-959b-9683efcfe056',
#               'x': [6905.0],
#               'y': [0.6932944256033238]},
#              {'mode': 'text',
#               'text': '322',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '8b60f359-2b98-49b2-ae6f-79b1978a1b18',
#               'x': [6935.0],
#               'y': [0.6441655952437951]},
#              {'mode': 'text',
#               'text': '524',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '4fe4a43a-f859-4bd2-b69a-9869ccd32de7',
#               'x': [6975.0],
#               'y': [0.43776076553401755]},
#              {'mode': 'text',
#               'text': '693',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'd294ac1b-ad6a-4e0e-a0c1-e648bc0c9001',
#               'x': [6965.0],
#               'y': [0.7157603385279231]},
#              {'mode': 'text',
#               'text': '378',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '5de21fb4-929d-49be-a075-e5963d7a865b',
#               'x': [6955.0],
#               'y': [0.836773691146542]},
#              {'mode': 'text',
#               'text': '525',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'a4076f81-054b-46ac-99fb-05f31bf14cc5',
#               'x': [6940.0],
#               'y': [1.6200637451668987]},
#              {'mode': 'text',
#               'text': '692',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'f860ac67-42c6-45e1-87a4-6b3972441e8c',
#               'x': [6912.5],
#               'y': [3.4021355979696235]},
#              {'mode': 'text',
#               'text': '248',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '070e46c1-d910-4180-a29e-8d4fd62b503b',
#               'x': [6867.5],
#               'y': [7.151823906658658]},
#              {'mode': 'text',
#               'text': '325',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '72fbb45f-6026-4e2f-8dbe-b104beba07c8',
#               'x': [6756.875],
#               'y': [9.966799118438567]},
#              {'mode': 'text',
#               'text': '687',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '42866c7a-fd14-4394-b53b-2741547edd65',
#               'x': [6680.0],
#               'y': [15.674754954777056]},
#              {'mode': 'text',
#               'text': '274',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '2a24146d-f501-406a-a0ab-35f18ad0b11e',
#               'x': [6597.5],
#               'y': [21.339834581397866]},
#              {'mode': 'text',
#               'text': '280',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'd876f428-079e-4b4e-8bbc-7eebac6eff50',
#               'x': [6226.640625],
#               'y': [60.241127203918694]},
#              {'mode': 'text',
#               'text': '287',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'f22ff7da-100a-4699-931d-5b4ed32ed79d',
#               'x': [5322.5244140625],
#               'y': [126.19283053880316]},
#              {'mode': 'text',
#               'text': '374',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '6ab70ee1-3a25-482d-990b-f8b6dc06e26f',
#               'x': [3801.1083984375],
#               'y': [186.5986388613386]},
#              {'mode': 'text',
#               'text': '276',
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '4d64fa5f-a99b-4b89-b198-c842037daf26',
#               'x': [786.68701171875],
#               'y': [522.274720087723]}],
#     'layout': {'font': {'size': 18},
#                'template': '...',
#                'title': {'font': {'size': 24}},
#                'xaxis': {'tickfont': {'size': 16}, 'title': {'font': {'size': 20}, 'text': 'Cluster'}},
#                'yaxis': {'tickfont': {'size': 16}, 'title': {'font': {'size': 20}, 'text': 'Distance'}}}
# })

# %% [markdown]
# <font size="+1" color="grey"><b> 2.2.4 Parallel Coordinate Plot</b></font><br/>

# %%
parallel_plot_2d = (parallel_widget.update_layout(
    # width=800,
    # height=600,
    font=dict(size=18),
    title_font=dict(size=24),
    xaxis=dict(title_font=dict(size=20), tickfont=dict(size=16)),
    yaxis=dict(title_font=dict(size=20), tickfont=dict(size=16))
))


# parallel_plot_2d.write_image("../../images/case1_2d_parallel_plot.png", width=800, height=400, scale=2)
display(parallel_plot_2d)
# Out:
# FigureWidget({
#     'data': [{'dimensions': [{'label': 't-SNE_Component_1',
#                               'values': array([-1.35362554, 12.17535686,  3.40371871, ..., 23.55991936, 19.96989059,
#                                                19.96037483])},
#                              {'label': 't-SNE_Component_2',
#                               'values': array([-1.69337952, -4.56390476,  4.65125751, ...,  2.67678857,  3.93712044,
#                                                 4.05621529])}],
#               'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#               'line': {'color': array([2., 2., 2., ..., 4., 4., 4.]),
#                        'coloraxis': 'coloraxis'},
#               'name': '',
#               'type': 'parcoords',
#               'uid': '5b3eb80e-a3ae-481b-a93a-8c088e8fcd99'}],
#     'layout': {'coloraxis': {'colorbar': {'title': {'text': 'Class'}},
#                              'colorscale': [[0.0, 'rgb(176, 242, 188)'],
#                                             [0.16666666666666666, 'rgb(137, 232,
#                                             172)'], [0.3333333333333333, 'rgb(103,
#                                             219, 165)'], [0.5, 'rgb(76, 200,
#                                             163)'], [0.6666666666666666, 'rgb(56,
#                                             178, 163)'], [0.8333333333333334,
#                                             'rgb(44, 152, 160)'], [1.0, 'rgb(37,
#                                             125, 152)']]},
#                'font': {'size': 18},
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 24}},
#                'xaxis': {'tickfont': {'size': 16}, 'title': {'font': {'size': 20}}},
#                'yaxis': {'tickfont': {'size': 16}, 'title': {'font': {'size': 20}}}}
# })

# %% [markdown]
# ##### All in one view

# %%
# display(grid_layout)

# %% [markdown]
# ## To be continued ...

# %%
pip install -r ../requirements.txt
# Out:
# Collecting altair==5.4.1 (from -r ../requirements.txt (line 1))
#   Using cached altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting altair-catplot==0.0.5 (from -r ../requirements.txt (line 2))
#   Using cached altair_catplot-0.0.5-py3-none-any.whl.metadata (27 kB)
# Collecting ansi2html==1.9.2 (from -r ../requirements.txt (line 3))
#   Using cached ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: appnope==0.1.4 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: asttokens==2.4.1 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (2.4.1)
# Collecting attrs==24.2.0 (from -r ../requirements.txt (line 6))
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting bleach==6.1.0 (from -r ../requirements.txt (line 7))
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting blinker==1.8.2 (from -r ../requirements.txt (line 8))
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting bokeh==3.6.0 (from -r ../requirements.txt (line 9))
#   Using cached bokeh-3.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting certifi==2024.8.30 (from -r ../requirements.txt (line 10))
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.4.0 (from -r ../requirements.txt (line 11))
#   Using cached charset_normalizer-3.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting click==8.1.7 (from -r ../requirements.txt (line 12))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle==3.0.0 (from -r ../requirements.txt (line 13))
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting colorcet==3.1.0 (from -r ../requirements.txt (line 14))
#   Using cached colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: comm==0.2.2 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 15)) (0.2.2)
# Collecting contourpy==1.3.0 (from -r ../requirements.txt (line 16))
#   Using cached contourpy-1.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler==0.12.1 (from -r ../requirements.txt (line 17))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash==2.18.1 (from -r ../requirements.txt (line 18))
#   Using cached dash-2.18.1-py3-none-any.whl.metadata (10 kB)
# Collecting dash-core-components==2.0.0 (from -r ../requirements.txt (line 19))
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-html-components==2.0.0 (from -r ../requirements.txt (line 20))
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-table==5.0.0 (from -r ../requirements.txt (line 21))
#   Using cached dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting dask==2024.9.1 (from -r ../requirements.txt (line 22))
#   Using cached dask-2024.9.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting datashader==0.16.3 (from -r ../requirements.txt (line 23))
#   Using cached datashader-0.16.3-py2.py3-none-any.whl.metadata (12 kB)
# Collecting debugpy==1.8.5 (from -r ../requirements.txt (line 24))
#   Using cached debugpy-1.8.5-cp311-cp311-macosx_12_0_universal2.whl.metadata (1.1 kB)
# Requirement already satisfied: decorator==5.1.1 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 25)) (5.1.1)
# Requirement already satisfied: executing==2.1.0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 26)) (2.1.0)
# Collecting fastjsonschema==2.20.0 (from -r ../requirements.txt (line 27))
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting Flask==3.0.3 (from -r ../requirements.txt (line 28))
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting fonttools==4.53.1 (from -r ../requirements.txt (line 29))
#   Using cached fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (162 kB)
# Collecting fsspec==2024.9.0 (from -r ../requirements.txt (line 30))
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting holoviews==1.19.1 (from -r ../requirements.txt (line 31))
#   Using cached holoviews-1.19.1-py3-none-any.whl.metadata (9.8 kB)
# Collecting idna==3.10 (from -r ../requirements.txt (line 32))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting importlib_metadata==8.5.0 (from -r ../requirements.txt (line 33))
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 34)) (6.29.5)
# Collecting ipython==8.27.0 (from -r ../requirements.txt (line 35))
#   Using cached ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting ipywidgets==8.1.5 (from -r ../requirements.txt (line 36))
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting itsdangerous==2.2.0 (from -r ../requirements.txt (line 37))
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jedi==0.19.1 (from -r ../requirements.txt (line 38))
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting Jinja2==3.1.4 (from -r ../requirements.txt (line 39))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib==1.4.2 (from -r ../requirements.txt (line 40))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting jsonschema==4.23.0 (from -r ../requirements.txt (line 41))
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonschema-specifications==2023.12.1 (from -r ../requirements.txt (line 42))
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyter-dash==0.4.2 (from -r ../requirements.txt (line 43))
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting jupyter_bokeh==4.0.5 (from -r ../requirements.txt (line 44))
#   Using cached jupyter_bokeh-4.0.5-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jupyter_client==8.6.3 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 45)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 46)) (5.7.2)
# Collecting jupyterlab_widgets==3.0.13 (from -r ../requirements.txt (line 47))
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting kaleido==0.2.1 (from -r ../requirements.txt (line 48))
#   Using cached kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting kiwisolver==1.4.7 (from -r ../requirements.txt (line 49))
#   Using cached kiwisolver-1.4.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting linkify-it-py==2.0.3 (from -r ../requirements.txt (line 50))
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting llvmlite==0.43.0 (from -r ../requirements.txt (line 51))
#   Using cached llvmlite-0.43.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting locket==1.0.0 (from -r ../requirements.txt (line 52))
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting Markdown==3.7 (from -r ../requirements.txt (line 53))
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting markdown-it-py==3.0.0 (from -r ../requirements.txt (line 54))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting MarkupSafe==3.0.1 (from -r ../requirements.txt (line 55))
#   Using cached MarkupSafe-3.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting matplotlib==3.9.2 (from -r ../requirements.txt (line 56))
#   Using cached matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 57)) (0.1.7)
# Collecting mdit-py-plugins==0.4.2 (from -r ../requirements.txt (line 58))
#   Using cached mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting mdurl==0.1.2 (from -r ../requirements.txt (line 59))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting multipledispatch==1.0.0 (from -r ../requirements.txt (line 60))
#   Using cached multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting narwhals==1.9.2 (from -r ../requirements.txt (line 61))
#   Using cached narwhals-1.9.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting nbformat==5.10.4 (from -r ../requirements.txt (line 62))
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 63)) (1.6.0)
# Collecting numba==0.60.0 (from -r ../requirements.txt (line 64))
#   Using cached numba-0.60.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting numpy==2.0.0 (from -r ../requirements.txt (line 65))
#   Using cached numpy-2.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (60 kB)
# Collecting packaging==24.1 (from -r ../requirements.txt (line 66))
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.2.2 (from -r ../requirements.txt (line 67))
#   Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting panel==1.5.2 (from -r ../requirements.txt (line 68))
#   Using cached panel-1.5.2-py3-none-any.whl.metadata (15 kB)
# Collecting param==2.1.1 (from -r ../requirements.txt (line 69))
#   Using cached param-2.1.1-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: parso==0.8.4 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 70)) (0.8.4)
# Collecting partd==1.4.2 (from -r ../requirements.txt (line 71))
#   Using cached partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pexpect==4.9.0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 72)) (4.9.0)
# Collecting pillow==10.4.0 (from -r ../requirements.txt (line 73))
#   Using cached pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: platformdirs==4.3.6 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 74)) (4.3.6)
# Collecting plotly==5.24.1 (from -r ../requirements.txt (line 75))
#   Using cached plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting polar_diagrams==1.2.0 (from -r ../requirements.txt (line 76))
#   Using cached polar_diagrams-1.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting prompt_toolkit==3.0.47 (from -r ../requirements.txt (line 77))
#   Using cached prompt_toolkit-3.0.47-py3-none-any.whl.metadata (6.4 kB)
# Collecting psutil==6.0.0 (from -r ../requirements.txt (line 78))
#   Using cached psutil-6.0.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (21 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 79)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 80)) (0.2.3)
# Collecting pyct==0.5.0 (from -r ../requirements.txt (line 81))
#   Using cached pyct-0.5.0-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: Pygments==2.18.0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 82)) (2.18.0)
# Collecting pynndescent==0.5.13 (from -r ../requirements.txt (line 83))
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting pyparsing==3.1.4 (from -r ../requirements.txt (line 84))
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 85)) (2.9.0.post0)
# Collecting pytz==2024.2 (from -r ../requirements.txt (line 86))
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pyviz_comms==3.0.3 (from -r ../requirements.txt (line 87))
#   Using cached pyviz_comms-3.0.3-py3-none-any.whl.metadata (7.7 kB)
# Collecting PyYAML==6.0.2 (from -r ../requirements.txt (line 88))
#   Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: pyzmq==26.2.0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 89)) (26.2.0)
# Collecting referencing==0.35.1 (from -r ../requirements.txt (line 90))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting requests==2.32.3 (from -r ../requirements.txt (line 91))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting retrying==1.3.4 (from -r ../requirements.txt (line 92))
#   Using cached retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting rpds-py==0.20.0 (from -r ../requirements.txt (line 93))
#   Using cached rpds_py-0.20.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting scikit-learn==1.5.2 (from -r ../requirements.txt (line 94))
#   Using cached scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting scipy==1.14.1 (from -r ../requirements.txt (line 95))
#   Using cached scipy-1.14.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting seaborn==0.13.2 (from -r ../requirements.txt (line 96))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: six==1.16.0 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 97)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.3 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 98)) (0.6.3)
# Collecting tenacity==9.0.0 (from -r ../requirements.txt (line 99))
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting threadpoolctl==3.5.0 (from -r ../requirements.txt (line 100))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting toolz==1.0.0 (from -r ../requirements.txt (line 101))
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: tornado==6.4.1 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 102)) (6.4.1)
# Collecting tqdm==4.66.5 (from -r ../requirements.txt (line 103))
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: traitlets==5.14.3 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 104)) (5.14.3)
# Requirement already satisfied: typing_extensions==4.12.2 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 105)) (4.12.2)
# Collecting tzdata==2024.1 (from -r ../requirements.txt (line 106))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting uc-micro-py==1.0.3 (from -r ../requirements.txt (line 107))
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting umap-learn==0.5.6 (from -r ../requirements.txt (line 108))
#   Using cached umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting urllib3==2.2.3 (from -r ../requirements.txt (line 109))
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting vega-datasets==0.9.0 (from -r ../requirements.txt (line 110))
#   Using cached vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting vl-convert-python==1.7.0 (from -r ../requirements.txt (line 111))
#   Using cached vl_convert_python-1.7.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from -r ../requirements.txt (line 112)) (0.2.13)
# Collecting webencodings==0.5.1 (from -r ../requirements.txt (line 113))
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting Werkzeug==3.0.4 (from -r ../requirements.txt (line 114))
#   Using cached werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting widgetsnbextension==4.0.13 (from -r ../requirements.txt (line 115))
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting xarray==2024.9.0 (from -r ../requirements.txt (line 116))
#   Using cached xarray-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting xyzservices==2024.9.0 (from -r ../requirements.txt (line 117))
#   Using cached xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting zipp==3.20.2 (from -r ../requirements.txt (line 118))
#   Using cached zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: setuptools in /Users/AwotoroE-Dev/Downloads/FlowMDP/.env/lib/python3.11/site-packages (from dash==2.18.1->-r ../requirements.txt (line 18)) (65.5.0)
# Using cached altair-5.4.1-py3-none-any.whl (658 kB)
# Using cached altair_catplot-0.0.5-py3-none-any.whl (30 kB)
# Using cached ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached bokeh-3.6.0-py3-none-any.whl (6.9 MB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached charset_normalizer-3.4.0-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Using cached colorcet-3.1.0-py3-none-any.whl (260 kB)
# Using cached contourpy-1.3.0-cp311-cp311-macosx_11_0_arm64.whl (250 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached dash-2.18.1-py3-none-any.whl (7.5 MB)
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Using cached dask-2024.9.1-py3-none-any.whl (1.3 MB)
# Using cached datashader-0.16.3-py2.py3-none-any.whl (18.3 MB)
# Using cached debugpy-1.8.5-cp311-cp311-macosx_12_0_universal2.whl (1.8 MB)
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached holoviews-1.19.1-py3-none-any.whl (5.0 MB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Using cached ipython-8.27.0-py3-none-any.whl (818 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Using cached jupyter_bokeh-4.0.5-py3-none-any.whl (148 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl (85.8 MB)
# Using cached kiwisolver-1.4.7-cp311-cp311-macosx_11_0_arm64.whl (64 kB)
# Using cached linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Using cached llvmlite-0.43.0-cp311-cp311-macosx_11_0_arm64.whl (28.8 MB)
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-3.0.1-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Using cached matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
# Using cached mdit_py_plugins-0.4.2-py3-none-any.whl (55 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Using cached narwhals-1.9.2-py3-none-any.whl (185 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached numba-0.60.0-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# Using cached numpy-2.0.0-cp311-cp311-macosx_11_0_arm64.whl (13.3 MB)
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Using cached pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
# Using cached panel-1.5.2-py3-none-any.whl (27.4 MB)
# Using cached param-2.1.1-py3-none-any.whl (116 kB)
# Using cached partd-1.4.2-py3-none-any.whl (18 kB)
# Using cached pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl (3.4 MB)
# Using cached plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Using cached polar_diagrams-1.2.0-py3-none-any.whl (28 kB)
# Using cached prompt_toolkit-3.0.47-py3-none-any.whl (386 kB)
# Using cached psutil-6.0.0-cp38-abi3-macosx_11_0_arm64.whl (251 kB)
# Using cached pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Using cached pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached pyviz_comms-3.0.3-py3-none-any.whl (83 kB)
# Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl (172 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Using cached rpds_py-0.20.0-cp311-cp311-macosx_11_0_arm64.whl (311 kB)
# Using cached scikit_learn-1.5.2-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
# Using cached scipy-1.14.1-cp311-cp311-macosx_12_0_arm64.whl (29.9 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Using cached umap_learn-0.5.6-py3-none-any.whl (85 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached vega_datasets-0.9.0-py3-none-any.whl (210 kB)
# Using cached vl_convert_python-1.7.0-cp37-abi3-macosx_11_0_arm64.whl (26.9 MB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached werkzeug-3.0.4-py3-none-any.whl (227 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached xarray-2024.9.0-py3-none-any.whl (1.2 MB)
# Using cached xyzservices-2024.9.0-py3-none-any.whl (85 kB)
# Using cached zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Installing collected packages: webencodings, pytz, multipledispatch, kaleido, fastjsonschema, dash-table, dash-html-components, dash-core-components, zipp, xyzservices, widgetsnbextension, vl-convert-python, urllib3, uc-micro-py, tzdata, tqdm, toolz, threadpoolctl, tenacity, rpds-py, retrying, PyYAML, pyparsing, psutil, prompt_toolkit, pillow, param, packaging, numpy, narwhals, mdurl, MarkupSafe, Markdown, locket, llvmlite, kiwisolver, jupyterlab_widgets, joblib, jedi, itsdangerous, idna, fsspec, fonttools, debugpy, cycler, colorcet, cloudpickle, click, charset-normalizer, certifi, blinker, bleach, attrs, ansi2html, Werkzeug, scipy, requests, referencing, pyviz_comms, pyct, plotly, partd, pandas, numba, markdown-it-py, linkify-it-py, Jinja2, importlib_metadata, contourpy, xarray, vega-datasets, scikit-learn, mdit-py-plugins, matplotlib, jsonschema-specifications, ipython, Flask, dask, bokeh, seaborn, pynndescent, polar_diagrams, panel, jsonschema, ipywidgets, datashader, dash, umap-learn, nbformat, jupyter-dash, jupyter_bokeh, holoviews, altair, altair-catplot
#   Attempting uninstall: psutil
#     Found existing installation: psutil 6.1.0
#     Uninstalling psutil-6.1.0:
#       Successfully uninstalled psutil-6.1.0
#   Attempting uninstall: prompt_toolkit
#     Found existing installation: prompt_toolkit 3.0.48
#     Uninstalling prompt_toolkit-3.0.48:
#       Successfully uninstalled prompt_toolkit-3.0.48
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.19.2
#     Uninstalling jedi-0.19.2:
#       Successfully uninstalled jedi-0.19.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.8
#     Uninstalling debugpy-1.8.8:
#       Successfully uninstalled debugpy-1.8.8
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.29.0
#     Uninstalling ipython-8.29.0:
#       Successfully uninstalled ipython-8.29.0
# Successfully installed Flask-3.0.3 Jinja2-3.1.4 Markdown-3.7 MarkupSafe-3.0.1 PyYAML-6.0.2 Werkzeug-3.0.4 altair-5.4.1 altair-catplot-0.0.5 ansi2html-1.9.2 attrs-24.2.0 bleach-6.1.0 blinker-1.8.2 bokeh-3.6.0 certifi-2024.8.30 charset-normalizer-3.4.0 click-8.1.7 cloudpickle-3.0.0 colorcet-3.1.0 contourpy-1.3.0 cycler-0.12.1 dash-2.18.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 dask-2024.9.1 datashader-0.16.3 debugpy-1.8.5 fastjsonschema-2.20.0 fonttools-4.53.1 fsspec-2024.9.0 holoviews-1.19.1 idna-3.10 importlib_metadata-8.5.0 ipython-8.27.0 ipywidgets-8.1.5 itsdangerous-2.2.0 jedi-0.19.1 joblib-1.4.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-dash-0.4.2 jupyter_bokeh-4.0.5 jupyterlab_widgets-3.0.13 kaleido-0.2.1 kiwisolver-1.4.7 linkify-it-py-2.0.3 llvmlite-0.43.0 locket-1.0.0 markdown-it-py-3.0.0 matplotlib-3.9.2 mdit-py-plugins-0.4.2 mdurl-0.1.2 multipledispatch-1.0.0 narwhals-1.9.2 nbformat-5.10.4 numba-0.60.0 numpy-2.0.0 packaging-24.1 pandas-2.2.2 panel-1.5.2 param-2.1.1 partd-1.4.2 pillow-10.4.0 plotly-5.24.1 polar_diagrams-1.2.0 prompt_toolkit-3.0.47 psutil-6.0.0 pyct-0.5.0 pynndescent-0.5.13 pyparsing-3.1.4 pytz-2024.2 pyviz_comms-3.0.3 referencing-0.35.1 requests-2.32.3 retrying-1.3.4 rpds-py-0.20.0 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 tenacity-9.0.0 threadpoolctl-3.5.0 toolz-1.0.0 tqdm-4.66.5 tzdata-2024.1 uc-micro-py-1.0.3 umap-learn-0.5.6 urllib3-2.2.3 vega-datasets-0.9.0 vl-convert-python-1.7.0 webencodings-0.5.1 widgetsnbextension-4.0.13 xarray-2024.9.0 xyzservices-2024.9.0 zipp-3.20.2
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
